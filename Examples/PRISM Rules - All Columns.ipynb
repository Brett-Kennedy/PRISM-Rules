# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification, make_blobs, fetch_openml
import sklearn.datasets as datasets

import sys
sys.path.append('../')
from prism_rules import PrismRules

# %% [markdown]
# This notebook provides an example of looking for all patterns in the data, not just those related to the target column.
#
# This may be done to understand the data, as opposed to discovering rules that are predictive of the target column.
#
# Here we take a sample dataset, the Wine dataset from sklearn's set of toy datasets, and provide an example of deriving the
# rules, where possible, for each column from the other columns.

# %%
data = datasets.load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Y'] = data['target']
display(df.head())

prism = PrismRules()

for col_name in df.columns:
    print()
    print("*********************************************************************************")
    print(f"Rules for {col_name}")
    print("*********************************************************************************")
    
    _ = prism.get_prism_rules(df, col_name, display_stats=False)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  Y
# 0                          3.92   1065.0  0
# 1                          3.40   1050.0  0
# 2                          3.17   1185.0  0
# 3                          3.45   1480.0  0
# 4                          2.93    735.0  0
# *********************************************************************************
# Rules for alcohol
# *********************************************************************************
#
# Target: Low
# color_intensity = Low AND nonflavanoid_phenols = Med AND alcalinity_of_ash = Med
# Y = 1 AND ash = High
# color_intensity = Low AND od280/od315_of_diluted_wines = Med AND Y = 1 AND flavanoids = Med
#
# Target: Med
# Y = 2 AND magnesium = High AND flavanoids = Low AND hue = Low
#
# Target: High
# Y = 0 AND ash = Med AND magnesium = High
# Y = 0 AND color_intensity = High AND alcalinity_of_ash = Low
# Y = 0 AND hue = High AND proline = High
#
# *********************************************************************************
# Rules for malic_acid
# *********************************************************************************
#
# Target: Low
# hue = High AND Y = 1 AND total_phenols = Med
# hue = High AND nonflavanoid_phenols = Low AND proanthocyanins = High
#
# Target: Med
# Y = 0 AND ash = Med AND flavanoids = High AND alcalinity_of_ash = Low
# Y = 0 AND nonflavanoid_phenols = Med AND proline = High
#
# Target: High
# Y = 2 AND magnesium = High AND total_phenols = Low
# Y = 2 AND color_intensity = Med
#
# *********************************************************************************
# Rules for ash
# *********************************************************************************
#
# Target: Low
# Y = 1 AND alcalinity_of_ash = Low AND hue = High
# magnesium = Low AND nonflavanoid_phenols = Low
# color_intensity = Low AND nonflavanoid_phenols = Med AND alcalinity_of_ash = Med
#
# Target: Med
#
# Target: High
#
# *********************************************************************************
# Rules for alcalinity_of_ash
# *********************************************************************************
#
# Target: Low
# Y = 0 AND ash = Low AND total_phenols = High
# Y = 0 AND total_phenols = Med AND proline = High AND color_intensity = Med
#
# Target: Med
# alcohol = Low AND nonflavanoid_phenols = Med AND ash = Low AND color_intensity = Low
#
# Target: High
# nonflavanoid_phenols = High AND flavanoids = Med
# Y = 2 AND ash = High AND od280/od315_of_diluted_wines = Low AND hue = Low
#
# *********************************************************************************
# Rules for magnesium
# *********************************************************************************
#
# Target: Low
# proline = Low AND od280/od315_of_diluted_wines = Med AND malic_acid = Low
# proline = Low AND proanthocyanins = Med AND Y = 1
# proline = Low AND ash = Low
#
# Target: Med
#
# Target: High
# flavanoids = High AND color_intensity = High AND alcohol = High AND alcalinity_of_ash = Low
#
# *********************************************************************************
# Rules for total_phenols
# *********************************************************************************
#
# Target: Low
# Y = 2 AND alcalinity_of_ash = Med AND proline = Med
# Y = 2 AND ash = Med AND alcohol = Med
# flavanoids = Low AND malic_acid = High AND hue = Low
#
# Target: Med
# flavanoids = Med AND proline = High
# flavanoids = Med AND alcalinity_of_ash = Med AND magnesium = Low
#
# Target: High
# flavanoids = High AND Y = 1
# flavanoids = High AND color_intensity = High AND proanthocyanins = High
# flavanoids = High AND ash = High
#
# *********************************************************************************
# Rules for flavanoids
# *********************************************************************************
#
# Target: Low
# Y = 2 AND nonflavanoid_phenols = High
# Y = 2 AND alcohol = Med
#
# Target: Med
# color_intensity = Low AND nonflavanoid_phenols = Med AND total_phenols = Med
# color_intensity = Low AND total_phenols = Med
#
# Target: High
# total_phenols = High AND color_intensity = High AND Y = 0
# total_phenols = High AND ash = High AND od280/od315_of_diluted_wines = High
# total_phenols = High AND color_intensity = Med
#
# *********************************************************************************
# Rules for nonflavanoid_phenols
# *********************************************************************************
#
# Target: Low
# proline = High AND ash = Low AND Y = 0
# flavanoids = High AND malic_acid = Low AND proanthocyanins = High
#
# Target: Med
#
# Target: High
# flavanoids = Low AND magnesium = Med AND proline = Med
# od280/od315_of_diluted_wines = Low AND magnesium = Low AND proline = Low
#
# *********************************************************************************
# Rules for proanthocyanins
# *********************************************************************************
#
# Target: Low
# Y = 2 AND color_intensity = Med
#
# Target: Med
# flavanoids = Med AND hue = High AND nonflavanoid_phenols = Low
#
# Target: High
# total_phenols = High AND ash = Low AND flavanoids = High
# total_phenols = High AND nonflavanoid_phenols = Low AND magnesium = High
# total_phenols = High AND ash = Med AND flavanoids = High
#
# *********************************************************************************
# Rules for color_intensity
# *********************************************************************************
#
# Target: Low
# Y = 1 AND flavanoids = Low
# Y = 1 AND hue = Med AND flavanoids = Med
# Y = 1 AND hue = Low
# Y = 1 AND alcohol = Low AND flavanoids = Med
#
# Target: Med
# Y = 0 AND flavanoids = Med
#
# Target: High
# Y = 2 AND alcohol = High AND hue = Low
# Y = 2 AND alcalinity_of_ash = High AND hue = Low
# alcohol = High AND magnesium = High AND proanthocyanins = High AND total_phenols = High AND proline = High
#
# *********************************************************************************
# Rules for hue
# *********************************************************************************
#
# Target: Low
# Y = 2 AND ash = Low
# Y = 2 AND color_intensity = High AND alcalinity_of_ash = High
# Y = 2 AND ash = Med AND total_phenols = Low
#
# Target: Med
#
# Target: High
# malic_acid = Low AND Y = 0 AND od280/od315_of_diluted_wines = Med
#
# *********************************************************************************
# Rules for od280/od315_of_diluted_wines
# *********************************************************************************
#
# Target: Low
# Y = 2 AND color_intensity = High
# Y = 2
#
# Target: Med
# hue = High AND proline = High AND malic_acid = Low AND Y = 0
#
# Target: High
#
# *********************************************************************************
# Rules for proline
# *********************************************************************************
#
# Target: Low
# Y = 1 AND nonflavanoid_phenols = High AND magnesium = Low
# Y = 1 AND magnesium = Low AND nonflavanoid_phenols = Low
#
# Target: Med
# Y = 2 AND alcohol = Med AND nonflavanoid_phenols = High AND malic_acid = High
#
# Target: High
# Y = 0 AND malic_acid = Med AND nonflavanoid_phenols = Low
# Y = 0 AND malic_acid = Low AND od280/od315_of_diluted_wines = Med
# Y = 0 AND malic_acid = Med AND nonflavanoid_phenols = Med
#
# *********************************************************************************
# Rules for Y
# *********************************************************************************
#
# Target: 0
# proline = High AND alcohol = High
# proline = High AND alcalinity_of_ash = Low
#
# Target: 1
# color_intensity = Low AND alcohol = Low
# color_intensity = Low
#
# Target: 2
# flavanoids = Low AND color_intensity = Med
# flavanoids = Low AND alcohol = High
# flavanoids = Low AND color_intensity = High AND hue = Low

# %%
# Again, with the statisitics for each rule

data = datasets.load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['Y'] = data['target']
display(df.head())

prism = PrismRules()

for col_name in df.columns:
    print()
    print("*********************************************************************************")
    print(f"Rules for {col_name}")
    print("*********************************************************************************")
    
    _ = prism.get_prism_rules(df, col_name, display_stats=True)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  Y
# 0                          3.92   1065.0  0
# 1                          3.40   1050.0  0
# 2                          3.17   1185.0  0
# 3                          3.45   1480.0  0
# 4                          2.93    735.0  0
# *********************************************************************************
# Rules for alcohol
# *********************************************************************************
#
# Target: Low
# color_intensity = Low AND nonflavanoid_phenols = Med AND alcalinity_of_ash = Med
#    Support:  the target has value: 'Low' for 100.000% of the 13 rows matching the rule
#    Coverage: the rule matches: 13 out of 60 rows for target value: 0. This is:
#       21.667% of total rows for target value: 0
#       7.303% of total rows in data
# Y = 1 AND ash = High
#    Support:  The target has value: 'Low' for 85.714% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 47 rows remaining for target value: '0'. This is:
#       25.532% of remaining rows for target value: '0'
#       20.000% of total rows for target value: 0
#       6.742% of total rows in data
# color_intensity = Low AND od280/od315_of_diluted_wines = Med AND Y = 1 AND flavanoids = Med
#    Support:  The target has value: 'Low' for 84.615% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 35 rows remaining for target value: '0'. This is:
#       31.429% of remaining rows for target value: '0'
#       18.333% of total rows for target value: 0
#       6.180% of total rows in data
#
# Target: Med
# Y = 2 AND magnesium = High AND flavanoids = Low AND hue = Low
#    Support:  the target has value: 'Med' for 85.714% of the 12 rows matching the rule
#    Coverage: the rule matches: 12 out of 59 rows for target value: 1. This is:
#       20.339% of total rows for target value: 1
#       6.742% of total rows in data
#
# Target: High
# Y = 0 AND ash = Med AND magnesium = High
#    Support:  the target has value: 'High' for 100.000% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 59 rows for target value: 2. This is:
#       18.644% of total rows for target value: 2
#       6.180% of total rows in data
# Y = 0 AND color_intensity = High AND alcalinity_of_ash = Low
#    Support:  The target has value: 'High' for 83.333% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 48 rows remaining for target value: '2'. This is:
#       20.833% of remaining rows for target value: '2'
#       16.949% of total rows for target value: 2
#       5.618% of total rows in data
# Y = 0 AND hue = High AND proline = High
#    Support:  The target has value: 'High' for 75.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 38 rows remaining for target value: '2'. This is:
#       31.579% of remaining rows for target value: '2'
#       20.339% of total rows for target value: 2
#       6.742% of total rows in data
#
# *********************************************************************************
# Rules for malic_acid
# *********************************************************************************
#
# Target: Low
# hue = High AND Y = 1 AND total_phenols = Med
#    Support:  the target has value: 'Low' for 78.571% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 60 rows for target value: 0. This is:
#       18.333% of total rows for target value: 0
#       6.180% of total rows in data
# hue = High AND nonflavanoid_phenols = Low AND proanthocyanins = High
#    Support:  The target has value: 'Low' for 76.923% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 49 rows remaining for target value: '0'. This is:
#       20.408% of remaining rows for target value: '0'
#       16.667% of total rows for target value: 0
#       5.618% of total rows in data
#
# Target: Med
# Y = 0 AND ash = Med AND flavanoids = High AND alcalinity_of_ash = Low
#    Support:  the target has value: 'Med' for 91.667% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 59 rows for target value: 1. This is:
#       18.644% of total rows for target value: 1
#       6.180% of total rows in data
# Y = 0 AND nonflavanoid_phenols = Med AND proline = High
#    Support:  The target has value: 'Med' for 78.571% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 48 rows remaining for target value: '1'. This is:
#       22.917% of remaining rows for target value: '1'
#       18.644% of total rows for target value: 1
#       6.180% of total rows in data
#
# Target: High
# Y = 2 AND magnesium = High AND total_phenols = Low
#    Support:  the target has value: 'High' for 92.857% of the 13 rows matching the rule
#    Coverage: the rule matches: 13 out of 59 rows for target value: 2. This is:
#       22.034% of total rows for target value: 2
#       7.303% of total rows in data
# Y = 2 AND color_intensity = Med
#    Support:  The target has value: 'High' for 90.909% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 46 rows remaining for target value: '2'. This is:
#       21.739% of remaining rows for target value: '2'
#       16.949% of total rows for target value: 2
#       5.618% of total rows in data
#
# *********************************************************************************
# Rules for ash
# *********************************************************************************
#
# Target: Low
# Y = 1 AND alcalinity_of_ash = Low AND hue = High
#    Support:  the target has value: 'Low' for 100.000% of the 12 rows matching the rule
#    Coverage: the rule matches: 12 out of 66 rows for target value: 0. This is:
#       18.182% of total rows for target value: 0
#       6.742% of total rows in data
# magnesium = Low AND nonflavanoid_phenols = Low
#    Support:  The target has value: 'Low' for 76.923% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 54 rows remaining for target value: '0'. This is:
#       18.519% of remaining rows for target value: '0'
#       15.152% of total rows for target value: 0
#       5.618% of total rows in data
# color_intensity = Low AND nonflavanoid_phenols = Med AND alcalinity_of_ash = Med
#    Support:  The target has value: 'Low' for 76.923% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 44 rows remaining for target value: '0'. This is:
#       22.727% of remaining rows for target value: '0'
#       15.152% of total rows for target value: 0
#       5.618% of total rows in data
#
# Target: Med
#   No rules imputed for target value Med. There are 56 rows for this class
#
# Target: High
#   No rules imputed for target value High. There are 56 rows for this class
#
# *********************************************************************************
# Rules for alcalinity_of_ash
# *********************************************************************************
#
# Target: Low
# Y = 0 AND ash = Low AND total_phenols = High
#    Support:  the target has value: 'Low' for 100.000% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 63 rows for target value: 0. This is:
#       15.873% of total rows for target value: 0
#       5.618% of total rows in data
# Y = 0 AND total_phenols = Med AND proline = High AND color_intensity = Med
#    Support:  The target has value: 'Low' for 84.615% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 53 rows remaining for target value: '0'. This is:
#       20.755% of remaining rows for target value: '0'
#       17.460% of total rows for target value: 0
#       6.180% of total rows in data
#
# Target: Med
# alcohol = Low AND nonflavanoid_phenols = Med AND ash = Low AND color_intensity = Low
#    Support:  the target has value: 'Med' for 83.333% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 66 rows for target value: 1. This is:
#       15.152% of total rows for target value: 1
#       5.618% of total rows in data
#
# Target: High
# nonflavanoid_phenols = High AND flavanoids = Med
#    Support:  the target has value: 'High' for 83.333% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 49 rows for target value: 2. This is:
#       20.408% of total rows for target value: 2
#       5.618% of total rows in data
# Y = 2 AND ash = High AND od280/od315_of_diluted_wines = Low AND hue = Low
#    Support:  The target has value: 'High' for 91.667% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 39 rows remaining for target value: '2'. This is:
#       28.205% of remaining rows for target value: '2'
#       22.449% of total rows for target value: 2
#       6.180% of total rows in data
#
# *********************************************************************************
# Rules for magnesium
# *********************************************************************************
# Target: Low
# proline = Low AND od280/od315_of_diluted_wines = Med AND malic_acid = Low
#    Support:  the target has value: 'Low' for 90.909% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 63 rows for target value: 0. This is:
#       15.873% of total rows for target value: 0
#       5.618% of total rows in data
# proline = Low AND proanthocyanins = Med AND Y = 1
#    Support:  The target has value: 'Low' for 84.615% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 53 rows remaining for target value: '0'. This is:
#       20.755% of remaining rows for target value: '0'
#       17.460% of total rows for target value: 0
#       6.180% of total rows in data
# proline = Low AND ash = Low
#    Support:  The target has value: 'Low' for 75.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 42 rows remaining for target value: '0'. This is:
#       28.571% of remaining rows for target value: '0'
#       19.048% of total rows for target value: 0
#       6.742% of total rows in data
#
# Target: Med
#   No rules imputed for target value Med. There are 58 rows for this class
#
# Target: High
# flavanoids = High AND color_intensity = High AND alcohol = High AND alcalinity_of_ash = Low
#    Support:  the target has value: 'High' for 81.250% of the 13 rows matching the rule
#    Coverage: the rule matches: 13 out of 57 rows for target value: 2. This is:
#       22.807% of total rows for target value: 2
#       7.303% of total rows in data
#
# *********************************************************************************
# Rules for total_phenols
# *********************************************************************************
#
# Target: Low
# Y = 2 AND alcalinity_of_ash = Med AND proline = Med
#    Support:  the target has value: 'Low' for 100.000% of the 14 rows matching the rule
#    Coverage: the rule matches: 14 out of 61 rows for target value: 0. This is:
#       22.951% of total rows for target value: 0
#       7.865% of total rows in data
# Y = 2 AND ash = Med AND alcohol = Med
#    Support:  The target has value: 'Low' for 100.000% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 47 rows remaining for target value: '0'. This is:
#       23.404% of remaining rows for target value: '0'
#       18.033% of total rows for target value: 0
#       6.180% of total rows in data
# flavanoids = Low AND malic_acid = High AND hue = Low
#    Support:  The target has value: 'Low' for 80.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 36 rows remaining for target value: '0'. This is:
#       33.333% of remaining rows for target value: '0'
#       19.672% of total rows for target value: 0
#       6.742% of total rows in data
#
# Target: Med
# flavanoids = Med AND proline = High
#    Support:  the target has value: 'Med' for 76.923% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 58 rows for target value: 1. This is:
#       17.241% of total rows for target value: 1
#       5.618% of total rows in data
# flavanoids = Med AND alcalinity_of_ash = Med AND magnesium = Low
#    Support:  The target has value: 'Med' for 91.667% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 48 rows remaining for target value: '1'. This is:
#       22.917% of remaining rows for target value: '1'
#       18.966% of total rows for target value: 1
#       6.180% of total rows in data
#
# Target: High
# flavanoids = High AND Y = 1
#    Support:  the target has value: 'High' for 100.000% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 59 rows for target value: 2. This is:
#       18.644% of total rows for target value: 2
#       6.180% of total rows in data
# flavanoids = High AND color_intensity = High AND proanthocyanins = High
#    Support:  The target has value: 'High' for 100.000% of the 20 remaining rows matching the rule
#    Coverage: The rule matches: 20 out of 48 rows remaining for target value: '2'. This is:
#       41.667% of remaining rows for target value: '2'
#       33.898% of total rows for target value: 2
#       11.236% of total rows in data
# flavanoids = High AND ash = High
#    Support:  The target has value: 'High' for 85.714% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 28 rows remaining for target value: '2'. This is:
#       42.857% of remaining rows for target value: '2'
#       20.339% of total rows for target value: 2
#       6.742% of total rows in data
#
# *********************************************************************************
# Rules for flavanoids
# *********************************************************************************
#
# Target: Low
# Y = 2 AND nonflavanoid_phenols = High
#    Support:  the target has value: 'Low' for 100.000% of the 31 rows matching the rule
#    Coverage: the rule matches: 31 out of 60 rows for target value: 0. This is:
#       51.667% of total rows for target value: 0
#       17.416% of total rows in data
# Y = 2 AND alcohol = Med
#    Support:  The target has value: 'Low' for 100.000% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 29 rows remaining for target value: '0'. This is:
#       37.931% of remaining rows for target value: '0'
#       18.333% of total rows for target value: 0
#       6.180% of total rows in data
#
# Target: Med
# color_intensity = Low AND nonflavanoid_phenols = Med AND total_phenols = Med
#    Support:  the target has value: 'Med' for 100.000% of the 16 rows matching the rule
#    Coverage: the rule matches: 16 out of 61 rows for target value: 1. This is:
#       26.230% of total rows for target value: 1
#       8.989% of total rows in data
# color_intensity = Low AND total_phenols = Med
#    Support:  The target has value: 'Med' for 78.571% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 45 rows remaining for target value: '1'. This is:
#       24.444% of remaining rows for target value: '1'
#       18.033% of total rows for target value: 1
#       6.180% of total rows in data
#
# Target: High
# total_phenols = High AND color_intensity = High AND Y = 0
#    Support:  the target has value: 'High' for 100.000% of the 24 rows matching the rule
#    Coverage: the rule matches: 24 out of 57 rows for target value: 2. This is:
#       42.105% of total rows for target value: 2
#       13.483% of total rows in data
# total_phenols = High AND ash = High AND od280/od315_of_diluted_wines = High
#    Support:  The target has value: 'High' for 100.000% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 33 rows remaining for target value: '2'. This is:
#       30.303% of remaining rows for target value: '2'
#       17.544% of total rows for target value: 2
#       5.618% of total rows in data
# total_phenols = High AND color_intensity = Med
#    Support:  The target has value: 'High' for 81.250% of the 13 remaining rows matching the rule
#    Coverage: The rule matches: 13 out of 23 rows remaining for target value: '2'. This is:
#       56.522% of remaining rows for target value: '2'
#       22.807% of total rows for target value: 2
#       7.303% of total rows in data
#
# *********************************************************************************
# Rules for nonflavanoid_phenols
# *********************************************************************************
#
# Target: Low
# proline = High AND ash = Low AND Y = 0
#    Support:  the target has value: 'Low' for 92.308% of the 12 rows matching the rule
#    Coverage: the rule matches: 12 out of 67 rows for target value: 0. This is:
#       17.910% of total rows for target value: 0
#       6.742% of total rows in data
# flavanoids = High AND malic_acid = Low AND proanthocyanins = High
#    Support:  The target has value: 'Low' for 91.667% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 55 rows remaining for target value: '0'. This is:
#       20.000% of remaining rows for target value: '0'
#       16.418% of total rows for target value: 0
#       6.180% of total rows in data
#
# Target: Med
#   No rules imputed for target value Med. There are 55 rows for this class
#
# Target: High
# flavanoids = Low AND magnesium = Med AND proline = Med
#    Support:  the target has value: 'High' for 100.000% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 56 rows for target value: 2. This is:
#       19.643% of total rows for target value: 2
#       6.180% of total rows in data
# od280/od315_of_diluted_wines = Low AND magnesium = Low AND proline = Low
#    Support:  The target has value: 'High' for 83.333% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 45 rows remaining for target value: '2'. This is:
#       22.222% of remaining rows for target value: '2'
#       17.857% of total rows for target value: 2
#       5.618% of total rows in data
#
# *********************************************************************************
# Rules for proanthocyanins
# *********************************************************************************
# Target: Low
# Y = 2 AND color_intensity = Med
#    Support:  the target has value: 'Low' for 100.000% of the 16 rows matching the rule
#    Coverage: the rule matches: 16 out of 63 rows for target value: 0. This is:
#       25.397% of total rows for target value: 0
#       8.989% of total rows in data
#
# Target: Med
# flavanoids = Med AND hue = High AND nonflavanoid_phenols = Low
#    Support:  the target has value: 'Med' for 76.923% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 56 rows for target value: 1. This is:
#       17.857% of total rows for target value: 1
#       5.618% of total rows in data
#
# Target: High
# total_phenols = High AND ash = Low AND flavanoids = High
#    Support:  the target has value: 'High' for 92.308% of the 12 rows matching the rule
#    Coverage: the rule matches: 12 out of 59 rows for target value: 2. This is:
#       20.339% of total rows for target value: 2
#       6.742% of total rows in data
# total_phenols = High AND nonflavanoid_phenols = Low AND magnesium = High
#    Support:  The target has value: 'High' for 90.909% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 47 rows remaining for target value: '2'. This is:
#       21.277% of remaining rows for target value: '2'
#       16.949% of total rows for target value: 2
#       5.618% of total rows in data
# total_phenols = High AND ash = Med AND flavanoids = High
#    Support:  The target has value: 'High' for 90.909% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 37 rows remaining for target value: '2'. This is:
#       27.027% of remaining rows for target value: '2'
#       16.949% of total rows for target value: 2
#       5.618% of total rows in data
#
# *********************************************************************************
# Rules for color_intensity
# *********************************************************************************
#
# Target: Low
# Y = 1 AND flavanoids = Low
#    Support:  the target has value: 'Low' for 92.308% of the 12 rows matching the rule
#    Coverage: the rule matches: 12 out of 60 rows for target value: 0. This is:
#       20.000% of total rows for target value: 0
#       6.742% of total rows in data
# Y = 1 AND hue = Med AND flavanoids = Med
#    Support:  The target has value: 'Low' for 100.000% of the 17 remaining rows matching the rule
#    Coverage: The rule matches: 17 out of 48 rows remaining for target value: '0'. This is:
#       35.417% of remaining rows for target value: '0'
#       28.333% of total rows for target value: 0
#       9.551% of total rows in data
# Y = 1 AND hue = Low
#    Support:  The target has value: 'Low' for 83.333% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 31 rows remaining for target value: '0'. This is:
#       32.258% of remaining rows for target value: '0'
#       16.667% of total rows for target value: 0
#       5.618% of total rows in data
# Y = 1 AND alcohol = Low AND flavanoids = Med
#    Support:  The target has value: 'Low' for 75.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 21 rows remaining for target value: '0'. This is:
#       57.143% of remaining rows for target value: '0'
#       20.000% of total rows for target value: 0
#       6.742% of total rows in data
#
# Target: Med
# Y = 0 AND flavanoids = Med
#    Support:  the target has value: 'Med' for 84.615% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 59 rows for target value: 1. This is:
#       18.644% of total rows for target value: 1
#       6.180% of total rows in data
#
# Target: High
# Y = 2 AND alcohol = High AND hue = Low
#    Support:  the target has value: 'High' for 90.909% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 59 rows for target value: 2. This is:
#       16.949% of total rows for target value: 2
#       5.618% of total rows in data
# Y = 2 AND alcalinity_of_ash = High AND hue = Low
#    Support:  The target has value: 'High' for 80.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 49 rows remaining for target value: '2'. This is:
#       24.490% of remaining rows for target value: '2'
#       20.339% of total rows for target value: 2
#       6.742% of total rows in data
# alcohol = High AND magnesium = High AND proanthocyanins = High AND total_phenols = High AND proline = High
#    Support:  The target has value: 'High' for 91.667% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 37 rows remaining for target value: '2'. This is:
#       29.730% of remaining rows for target value: '2'
#       18.644% of total rows for target value: 2
#       6.180% of total rows in data
#
# *********************************************************************************
# Rules for hue
# *********************************************************************************
#
# Target: Low
# Y = 2 AND ash = Low
#    Support:  the target has value: 'Low' for 100.000% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 60 rows for target value: 0. This is:
#       18.333% of total rows for target value: 0
#       6.180% of total rows in data
# Y = 2 AND color_intensity = High AND alcalinity_of_ash = High
#    Support:  The target has value: 'Low' for 100.000% of the 17 remaining rows matching the rule
#    Coverage: The rule matches: 17 out of 49 rows remaining for target value: '0'. This is:
#       34.694% of remaining rows for target value: '0'
#       28.333% of total rows for target value: 0
#       9.551% of total rows in data
# Y = 2 AND ash = Med AND total_phenols = Low
#    Support:  The target has value: 'Low' for 100.000% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 32 rows remaining for target value: '0'. This is:
#       34.375% of remaining rows for target value: '0'
#       18.333% of total rows for target value: 0
#       6.180% of total rows in data
#
# Target: Med
#   No rules imputed for target value Med. There are 62 rows for this class
#
# Target: High
# malic_acid = Low AND Y = 0 AND od280/od315_of_diluted_wines = Med
#    Support:  the target has value: 'High' for 90.909% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 56 rows for target value: 2. This is:
#       17.857% of total rows for target value: 2
#       5.618% of total rows in data
#
# *********************************************************************************
# Rules for od280/od315_of_diluted_wines
# *********************************************************************************
#
# Target: Low
# Y = 2 AND color_intensity = High
#    Support:  the target has value: 'Low' for 100.000% of the 32 rows matching the rule
#    Coverage: the rule matches: 32 out of 60 rows for target value: 0. This is:
#       53.333% of total rows for target value: 0
#       17.978% of total rows in data
# Y = 2
#    Support:  The target has value: 'Low' for 87.500% of the 14 remaining rows matching the rule
#    Coverage: The rule matches: 14 out of 28 rows remaining for target value: '0'. This is:
#       50.000% of remaining rows for target value: '0'
#       23.333% of total rows for target value: 0
#       7.865% of total rows in data
#
# Target: Med
# hue = High AND proline = High AND malic_acid = Low AND Y = 0
#    Support:  the target has value: 'Med' for 83.333% of the 10 rows matching the rule
#    Coverage: the rule matches: 10 out of 59 rows for target value: 1. This is:
#       16.949% of total rows for target value: 1
#       5.618% of total rows in data
#
# Target: High
#   No rules imputed for target value High. There are 59 rows for this class
#
# *********************************************************************************
# Rules for proline
# *********************************************************************************
#
# Target: Low
# Y = 1 AND nonflavanoid_phenols = High AND magnesium = Low
#    Support:  the target has value: 'Low' for 92.308% of the 12 rows matching the rule
#    Coverage: the rule matches: 12 out of 61 rows for target value: 0. This is:
#       19.672% of total rows for target value: 0
#       6.742% of total rows in data
# Y = 1 AND magnesium = Low AND nonflavanoid_phenols = Low
#    Support:  The target has value: 'Low' for 78.571% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 49 rows remaining for target value: '0'. This is:
#       22.449% of remaining rows for target value: '0'
#       18.033% of total rows for target value: 0
#       6.180% of total rows in data
#
# Target: Med
# Y = 2 AND alcohol = Med AND nonflavanoid_phenols = High AND malic_acid = High
#    Support:  the target has value: 'Med' for 84.615% of the 11 rows matching the rule
#    Coverage: the rule matches: 11 out of 58 rows for target value: 1. This is:
#       18.966% of total rows for target value: 1
#       6.180% of total rows in data
#
# Target: High
# Y = 0 AND malic_acid = Med AND nonflavanoid_phenols = Low
#    Support:  the target has value: 'High' for 100.000% of the 18 rows matching the rule
#    Coverage: the rule matches: 18 out of 59 rows for target value: 2. This is:
#       30.508% of total rows for target value: 2
#       10.112% of total rows in data
# Y = 0 AND malic_acid = Low AND od280/od315_of_diluted_wines = Med
#    Support:  The target has value: 'High' for 100.000% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 41 rows remaining for target value: '2'. This is:
#       26.829% of remaining rows for target value: '2'
#       18.644% of total rows for target value: 2
#       6.180% of total rows in data
# Y = 0 AND malic_acid = Med AND nonflavanoid_phenols = Med
#    Support:  The target has value: 'High' for 93.333% of the 14 remaining rows matching the rule
#    Coverage: The rule matches: 14 out of 30 rows remaining for target value: '2'. This is:
#       46.667% of remaining rows for target value: '2'
#       23.729% of total rows for target value: 2
#       7.865% of total rows in data
#
# *********************************************************************************
# Rules for Y
# *********************************************************************************
# Target: 0
# proline = High AND alcohol = High
#    Support:  the target has value: '0' for 100.000% of the 39 rows matching the rule
#    Coverage: the rule matches: 39 out of 59 rows for target value: 0. This is:
#       66.102% of total rows for target value: 0
#       21.910% of total rows in data
# proline = High AND alcalinity_of_ash = Low
#    Support:  The target has value: '0' for 100.000% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 20 rows remaining for target value: '0'. This is:
#       50.000% of remaining rows for target value: '0'
#       16.949% of total rows for target value: 0
#       5.618% of total rows in data
#
# Target: 1
# color_intensity = Low AND alcohol = Low
#    Support:  the target has value: '1' for 100.000% of the 46 rows matching the rule
#    Coverage: the rule matches: 46 out of 71 rows for target value: 1. This is:
#       64.789% of total rows for target value: 1
#       25.843% of total rows in data
# color_intensity = Low
#    Support:  The target has value: '1' for 78.571% of the 11 remaining rows matching the rule
#    Coverage: The rule matches: 11 out of 25 rows remaining for target value: '1'. This is:
#       44.000% of remaining rows for target value: '1'
#       15.493% of total rows for target value: 1
#       6.180% of total rows in data
#
# Target: 2
# flavanoids = Low AND color_intensity = Med
#    Support:  the target has value: '2' for 100.000% of the 16 rows matching the rule
#    Coverage: the rule matches: 16 out of 48 rows for target value: 2. This is:
#       33.333% of total rows for target value: 2
#       8.989% of total rows in data
# flavanoids = Low AND alcohol = High
#    Support:  The target has value: '2' for 100.000% of the 10 remaining rows matching the rule
#    Coverage: The rule matches: 10 out of 32 rows remaining for target value: '2'. This is:
#       31.250% of remaining rows for target value: '2'
#       20.833% of total rows for target value: 2
#       5.618% of total rows in data
# flavanoids = Low AND color_intensity = High AND hue = Low
#    Support:  The target has value: '2' for 100.000% of the 21 remaining rows matching the rule
#    Coverage: The rule matches: 21 out of 22 rows remaining for target value: '2'. This is:
#       95.455% of remaining rows for target value: '2'
#       43.750% of total rows for target value: 2
#       11.798% of total rows in data
